# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities
#
# Drew Barnhart

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# #installed citipy
# ! pip install citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
for i, city in enumerate(cities[:3]):

    print(i,city)
    
# i = index, city = name/value
# Out:
# 0 taolanaro
# 1 butaritari
# 2 busselton

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric"

# ^^^ f will take value within curly bracket(variable) and put it within the string

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+"&q="+city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities VV#when using try its when a code might have an error
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

print(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | udupi
# Processing Record 5 of Set 1 | craig
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | jacobina
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | quatre cocos
# Processing Record 12 of Set 1 | sao filipe
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | lamu
# Processing Record 15 of Set 1 | oriximina
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | darlowo
# Processing Record 18 of Set 1 | cayenne
# Processing Record 19 of Set 1 | airai
# Processing Record 20 of Set 1 | borba
# Processing Record 21 of Set 1 | mountain home
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | natal
# Processing Record 24 of Set 1 | kathmandu
# Processing Record 25 of Set 1 | salalah
# Processing Record 26 of Set 1 | nome
# Processing Record 27 of Set 1 | henties bay
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | huntingdon
# Processing Record 31 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 1 | margate
# Processing Record 34 of Set 1 | synya
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | luderitz
# Processing Record 37 of Set 1 | flinders
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | kemise
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | litovko
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | pushkino
# Processing Record 46 of Set 1 | madang
# Processing Record 47 of Set 1 | puerto carreno
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | mount gambier
# Processing Record 50 of Set 1 | luoyang
# Processing Record 0 of Set 2 | torbay
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | dunedin
# Processing Record 3 of Set 2 | gillette
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | canoas
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | bilibino
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | steamboat springs
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | seoul
# Processing Record 17 of Set 2 | neuquen
# Processing Record 18 of Set 2 | denpasar
# Processing Record 19 of Set 2 | methoni
# Processing Record 20 of Set 2 | sinegorye
# Processing Record 21 of Set 2 | cidreira
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | chickasha
# Processing Record 24 of Set 2 | chicama
# Processing Record 25 of Set 2 | kavieng
# Processing Record 26 of Set 2 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | port keats
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | benalla
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | nelson bay
# Processing Record 34 of Set 2 | cairns
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | sechura
# Processing Record 39 of Set 2 | veraval
# Processing Record 40 of Set 2 | arcachon
# Processing Record 41 of Set 2 | tura
# Processing Record 42 of Set 2 | oranjemund
# Processing Record 43 of Set 2 | andilamena
# Processing Record 44 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 2 | arteaga
# Processing Record 46 of Set 2 | la ronge
# Processing Record 47 of Set 2 | zapolyarnyy
# Processing Record 48 of Set 2 | qaqortoq
# Processing Record 49 of Set 2 | imeni poliny osipenko
# Processing Record 0 of Set 3 | chiang klang
# Processing Record 1 of Set 3 | lincoln
# Processing Record 2 of Set 3 | camacha
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | otavi
# Processing Record 5 of Set 3 | lata
# Processing Record 6 of Set 3 | nanortalik
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | gizo
# Processing Record 9 of Set 3 | elat
# Processing Record 10 of Set 3 | berdigestyakh
# Processing Record 11 of Set 3 | rolla
# Processing Record 12 of Set 3 | chenzhou
# Processing Record 13 of Set 3 | hervey bay
# Processing Record 14 of Set 3 | hasaki
# Processing Record 15 of Set 3 | cape town
# Processing Record 16 of Set 3 | sangar
# Processing Record 17 of Set 3 | os
# City not found. Skipping...
# Processing Record 18 of Set 3 | iwaki
# Processing Record 19 of Set 3 | ostrovnoy
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | angoram
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | muisne
# Processing Record 24 of Set 3 | baghmara
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | barcelos
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | port lincoln
# Processing Record 29 of Set 3 | viedma
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | namibe
# Processing Record 32 of Set 3 | qaanaaq
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | lokken verk
# City not found. Skipping...
# Processing Record 35 of Set 3 | pochutla
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | egvekinot
# Processing Record 38 of Set 3 | karlshamn
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | pisco
# Processing Record 41 of Set 3 | katherine
# Processing Record 42 of Set 3 | cerinza
# Processing Record 43 of Set 3 | adrar
# Processing Record 44 of Set 3 | yarada
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | bredasdorp
# Processing Record 47 of Set 3 | kavaratti
# Processing Record 48 of Set 3 | lavrentiya
# Processing Record 49 of Set 3 | itarema
# Processing Record 0 of Set 4 | vila velha
# Processing Record 1 of Set 4 | waipawa
# Processing Record 2 of Set 4 | bayji
# Processing Record 3 of Set 4 | mar del plata
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | sawtell
# Processing Record 6 of Set 4 | meiningen
# Processing Record 7 of Set 4 | zhigansk
# Processing Record 8 of Set 4 | port hedland
# Processing Record 9 of Set 4 | xinzhou
# Processing Record 10 of Set 4 | college
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | vila franca do campo
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | banda aceh
# Processing Record 15 of Set 4 | christchurch
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | fortuna
# Processing Record 18 of Set 4 | troutdale
# Processing Record 19 of Set 4 | puerto leguizamo
# Processing Record 20 of Set 4 | souillac
# Processing Record 21 of Set 4 | safaga
# Processing Record 22 of Set 4 | san andres
# Processing Record 23 of Set 4 | nouadhibou
# Processing Record 24 of Set 4 | kimberley
# Processing Record 25 of Set 4 | puerto ayora
# Processing Record 26 of Set 4 | along
# Processing Record 27 of Set 4 | asau
# Processing Record 28 of Set 4 | pallisa
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | khani
# Processing Record 31 of Set 4 | diffa
# Processing Record 32 of Set 4 | konstantinovka
# Processing Record 33 of Set 4 | half moon bay
# Processing Record 34 of Set 4 | killybegs
# Processing Record 35 of Set 4 | cooma
# Processing Record 36 of Set 4 | port-gentil
# Processing Record 37 of Set 4 | udachnyy
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | jacareacanga
# Processing Record 40 of Set 4 | kangaatsiaq
# Processing Record 41 of Set 4 | alghero
# Processing Record 42 of Set 4 | westport
# Processing Record 43 of Set 4 | ouesso
# Processing Record 44 of Set 4 | srednekolymsk
# Processing Record 45 of Set 4 | sinnamary
# Processing Record 46 of Set 4 | prilep
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | zhengjiatun
# Processing Record 49 of Set 4 | shingu
# Processing Record 0 of Set 5 | valdivia
# Processing Record 1 of Set 5 | clyde river
# Processing Record 2 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | yar-sale
# Processing Record 6 of Set 5 | antalaha
# Processing Record 7 of Set 5 | tuatapere
# Processing Record 8 of Set 5 | bengkulu
# Processing Record 9 of Set 5 | hofn
# Processing Record 10 of Set 5 | pangnirtung
# Processing Record 11 of Set 5 | georgiyevka
# Processing Record 12 of Set 5 | hami
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | suifenhe
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | kamenka
# Processing Record 17 of Set 5 | marsa matruh
# Processing Record 18 of Set 5 | japura
# Processing Record 19 of Set 5 | wenling
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | ureki
# Processing Record 22 of Set 5 | stokmarknes
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | kikwit
# Processing Record 25 of Set 5 | naze
# Processing Record 26 of Set 5 | beloha
# Processing Record 27 of Set 5 | maxixe
# Processing Record 28 of Set 5 | biloela
# Processing Record 29 of Set 5 | tautira
# Processing Record 30 of Set 5 | aktash
# Processing Record 31 of Set 5 | blackwater
# Processing Record 32 of Set 5 | rawson
# Processing Record 33 of Set 5 | jawa
# Processing Record 34 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 5 | kilimatinde
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | biak
# Processing Record 38 of Set 5 | padang
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | rio gallegos
# Processing Record 41 of Set 5 | tukrah
# Processing Record 42 of Set 5 | tomohon
# Processing Record 43 of Set 5 | laguna
# Processing Record 44 of Set 5 | chara
# Processing Record 45 of Set 5 | port augusta
# Processing Record 46 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 5 | verkhnyaya inta
# Processing Record 48 of Set 5 | coquimbo
# Processing Record 49 of Set 5 | komsomolskiy
# Processing Record 0 of Set 6 | mehamn
# Processing Record 1 of Set 6 | ponta delgada
# Processing Record 2 of Set 6 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 3 of Set 6 | fairbanks
# Processing Record 4 of Set 6 | miri
# Processing Record 5 of Set 6 | saint-joseph
# Processing Record 6 of Set 6 | agirish
# Processing Record 7 of Set 6 | sisauli
# Processing Record 8 of Set 6 | atar
# Processing Record 9 of Set 6 | vanimo
# Processing Record 10 of Set 6 | avarua
# Processing Record 11 of Set 6 | nayoro
# Processing Record 12 of Set 6 | gladstone
# Processing Record 13 of Set 6 | cabedelo
# Processing Record 14 of Set 6 | korla
# Processing Record 15 of Set 6 | muravlenko
# Processing Record 16 of Set 6 | santa rosa
# Processing Record 17 of Set 6 | pevek
# Processing Record 18 of Set 6 | lalibela
# Processing Record 19 of Set 6 | salou
# Processing Record 20 of Set 6 | pacific grove
# Processing Record 21 of Set 6 | yeppoon
# Processing Record 22 of Set 6 | arraial do cabo
# Processing Record 23 of Set 6 | marzuq
# Processing Record 24 of Set 6 | biograd na moru
# Processing Record 25 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 6 | alofi
# Processing Record 27 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 6 | salta
# Processing Record 29 of Set 6 | narsaq
# Processing Record 30 of Set 6 | terenga
# City not found. Skipping...
# Processing Record 31 of Set 6 | puerto escondido
# Processing Record 32 of Set 6 | eureka
# Processing Record 33 of Set 6 | olafsvik
# Processing Record 34 of Set 6 | northam
# Processing Record 35 of Set 6 | juneau
# Processing Record 36 of Set 6 | kahului
# Processing Record 37 of Set 6 | victoria
# Processing Record 38 of Set 6 | skjervoy
# Processing Record 39 of Set 6 | laiyang
# Processing Record 40 of Set 6 | touros
# Processing Record 41 of Set 6 | berlevag
# Processing Record 42 of Set 6 | oktyabrskiy
# Processing Record 43 of Set 6 | saint-pierre
# Processing Record 44 of Set 6 | dukat
# Processing Record 45 of Set 6 | mandalgovi
# Processing Record 46 of Set 6 | vestmannaeyjar
# Processing Record 47 of Set 6 | pandan
# Processing Record 48 of Set 6 | yulara
# Processing Record 49 of Set 6 | cape canaveral
# Processing Record 0 of Set 7 | shihezi
# Processing Record 1 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 7 | constitucion
# Processing Record 3 of Set 7 | acapulco
# Processing Record 4 of Set 7 | janauba
# Processing Record 5 of Set 7 | areosa
# Processing Record 6 of Set 7 | nioro
# Processing Record 7 of Set 7 | solnechnyy
# Processing Record 8 of Set 7 | kabompo
# Processing Record 9 of Set 7 | havoysund
# Processing Record 10 of Set 7 | harper
# Processing Record 11 of Set 7 | lisakovsk
# Processing Record 12 of Set 7 | belmonte
# Processing Record 13 of Set 7 | san quintin
# Processing Record 14 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 7 | bambanglipuro
# Processing Record 16 of Set 7 | coracora
# Processing Record 17 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 7 | shirokiy
# Processing Record 19 of Set 7 | sur
# Processing Record 20 of Set 7 | le port
# Processing Record 21 of Set 7 | zaraza
# Processing Record 22 of Set 7 | bintulu
# Processing Record 23 of Set 7 | yeltsovka
# City not found. Skipping...
# Processing Record 24 of Set 7 | sioux lookout
# Processing Record 25 of Set 7 | skowhegan
# Processing Record 26 of Set 7 | ixtapa
# Processing Record 27 of Set 7 | khao yoi
# Processing Record 28 of Set 7 | fenelon falls
# Processing Record 29 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 7 | washington
# Processing Record 31 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 7 | tual
# Processing Record 33 of Set 7 | vityazevo
# Processing Record 34 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | garbolovo
# Processing Record 37 of Set 7 | anadyr
# Processing Record 38 of Set 7 | ukiah
# Processing Record 39 of Set 7 | chiplun
# Processing Record 40 of Set 7 | cap malheureux
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 7 | acarau
# Processing Record 44 of Set 7 | shellbrook
# Processing Record 45 of Set 7 | chokurdakh
# Processing Record 46 of Set 7 | norman wells
# Processing Record 47 of Set 7 | raudeberg
# Processing Record 48 of Set 7 | omsukchan
# Processing Record 49 of Set 7 | sibu
# Processing Record 0 of Set 8 | afyonkarahisar
# Processing Record 1 of Set 8 | college station
# Processing Record 2 of Set 8 | ust-nera
# Processing Record 3 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 8 | cerqueira cesar
# Processing Record 5 of Set 8 | los algarrobos
# Processing Record 6 of Set 8 | cuauhtemoc
# Processing Record 7 of Set 8 | halvad
# Processing Record 8 of Set 8 | huarmey
# Processing Record 9 of Set 8 | leningradskiy
# Processing Record 10 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 8 | ojinaga
# Processing Record 12 of Set 8 | isangel
# Processing Record 13 of Set 8 | kungurtug
# Processing Record 14 of Set 8 | kununurra
# Processing Record 15 of Set 8 | baykit
# Processing Record 16 of Set 8 | ayorou
# Processing Record 17 of Set 8 | iturama
# Processing Record 18 of Set 8 | varzea da palma
# Processing Record 19 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 8 | bend
# Processing Record 21 of Set 8 | san rafael
# Processing Record 22 of Set 8 | radolfzell
# Processing Record 23 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 8 | jiaocheng
# Processing Record 25 of Set 8 | vila
# Processing Record 26 of Set 8 | bubaque
# Processing Record 27 of Set 8 | saint anthony
# Processing Record 28 of Set 8 | yokadouma
# Processing Record 29 of Set 8 | glendive
# Processing Record 30 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 31 of Set 8 | kazanskoye
# Processing Record 32 of Set 8 | port hueneme
# Processing Record 33 of Set 8 | cabo san lucas
# Processing Record 34 of Set 8 | east wenatchee bench
# Processing Record 35 of Set 8 | nova olimpia
# Processing Record 36 of Set 8 | saldanha
# Processing Record 37 of Set 8 | nanakuli
# Processing Record 38 of Set 8 | klaksvik
# Processing Record 39 of Set 8 | richards bay
# Processing Record 40 of Set 8 | buzmeyin
# Processing Record 41 of Set 8 | yakeshi
# Processing Record 42 of Set 8 | maniitsoq
# Processing Record 43 of Set 8 | nizwa
# Processing Record 44 of Set 8 | beitbridge
# Processing Record 45 of Set 8 | rovenki
# Processing Record 46 of Set 8 | verdun
# Processing Record 47 of Set 8 | freising
# Processing Record 48 of Set 8 | hualmay
# Processing Record 49 of Set 8 | bud
# Processing Record 0 of Set 9 | vuktyl
# Processing Record 1 of Set 9 | zhanakorgan
# Processing Record 2 of Set 9 | zhanaozen
# Processing Record 3 of Set 9 | mandera
# Processing Record 4 of Set 9 | geraldton
# Processing Record 5 of Set 9 | havre-saint-pierre
# Processing Record 6 of Set 9 | hobyo
# Processing Record 7 of Set 9 | grindavik
# Processing Record 8 of Set 9 | mao
# Processing Record 9 of Set 9 | bandarbeyla
# Processing Record 10 of Set 9 | broken hill
# Processing Record 11 of Set 9 | banfora
# Processing Record 12 of Set 9 | bereda
# Processing Record 13 of Set 9 | borodino
# Processing Record 14 of Set 9 | ketchikan
# Processing Record 15 of Set 9 | ballina
# Processing Record 16 of Set 9 | ulaangom
# Processing Record 17 of Set 9 | fuxin
# Processing Record 18 of Set 9 | teahupoo
# Processing Record 19 of Set 9 | riyadh
# Processing Record 20 of Set 9 | malard
# Processing Record 21 of Set 9 | springfield
# Processing Record 22 of Set 9 | matagami
# Processing Record 23 of Set 9 | usinsk
# Processing Record 24 of Set 9 | sug-aksy
# City not found. Skipping...
# Processing Record 25 of Set 9 | aketi
# Processing Record 26 of Set 9 | turukhansk
# Processing Record 27 of Set 9 | sumbe
# Processing Record 28 of Set 9 | aguimes
# Processing Record 29 of Set 9 | tessalit
# Processing Record 30 of Set 9 | brasilia de minas
# Processing Record 31 of Set 9 | mataram
# Processing Record 32 of Set 9 | zaozerne
# Processing Record 33 of Set 9 | matamoros
# Processing Record 34 of Set 9 | lepe
# Processing Record 35 of Set 9 | tokur
# Processing Record 36 of Set 9 | paralimni
# Processing Record 37 of Set 9 | waingapu
# Processing Record 38 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 39 of Set 9 | ancud
# Processing Record 40 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 9 | ronneby
# Processing Record 42 of Set 9 | uyuni
# Processing Record 43 of Set 9 | tiruchchendur
# Processing Record 44 of Set 9 | bumba
# Processing Record 45 of Set 9 | tucurui
# Processing Record 46 of Set 9 | kokopo
# Processing Record 47 of Set 9 | nishihara
# Processing Record 48 of Set 9 | matara
# Processing Record 49 of Set 9 | husavik
# Processing Record 0 of Set 10 | kirakira
# Processing Record 1 of Set 10 | kutum
# Processing Record 2 of Set 10 | lorengau
# Processing Record 3 of Set 10 | ahuimanu
# Processing Record 4 of Set 10 | monywa
# Processing Record 5 of Set 10 | port blair
# Processing Record 6 of Set 10 | byron bay
# Processing Record 7 of Set 10 | dakar
# Processing Record 8 of Set 10 | namatanai
# Processing Record 9 of Set 10 | nzega
# Processing Record 10 of Set 10 | road town
# Processing Record 11 of Set 10 | mangan
# Processing Record 12 of Set 10 | prainha
# Processing Record 13 of Set 10 | dingle
# Processing Record 14 of Set 10 | valparaiso
# Processing Record 15 of Set 10 | coihaique
# Processing Record 16 of Set 10 | sterling
# Processing Record 17 of Set 10 | haines junction
# Processing Record 18 of Set 10 | guiberoua
# Processing Record 19 of Set 10 | hargeysa
# Processing Record 20 of Set 10 | north bend
# Processing Record 21 of Set 10 | san luis
# Processing Record 22 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 23 of Set 10 | katsuura
# Processing Record 24 of Set 10 | vardo
# Processing Record 25 of Set 10 | mastic beach
# Processing Record 26 of Set 10 | ellisras
# Processing Record 27 of Set 10 | burns lake
# Processing Record 28 of Set 10 | lagoa
# Processing Record 29 of Set 10 | waunakee
# Processing Record 30 of Set 10 | terra santa
# Processing Record 31 of Set 10 | jalu
# Processing Record 32 of Set 10 | abonnema
# Processing Record 33 of Set 10 | gisborne
# Processing Record 34 of Set 10 | svarstad
# Processing Record 35 of Set 10 | san ramon
# Processing Record 36 of Set 10 | severnyy
# Processing Record 37 of Set 10 | hazorasp
# Processing Record 38 of Set 10 | saint-georges
# Processing Record 39 of Set 10 | aksu
# Processing Record 40 of Set 10 | sitka
# Processing Record 41 of Set 10 | sao gabriel da cachoeira
# Processing Record 42 of Set 10 | boundiali
# Processing Record 43 of Set 10 | nantucket
# Processing Record 44 of Set 10 | jumla
# Processing Record 45 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 10 | grand gaube
# Processing Record 47 of Set 10 | conde
# Processing Record 48 of Set 10 | dharmavaram
# Processing Record 49 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 0 of Set 11 | barmer
# Processing Record 1 of Set 11 | vagur
# Processing Record 2 of Set 11 | kilindoni
# Processing Record 3 of Set 11 | calabozo
# Processing Record 4 of Set 11 | lat yao
# Processing Record 5 of Set 11 | barra
# Processing Record 6 of Set 11 | xining
# Processing Record 7 of Set 11 | lodja
# Processing Record 8 of Set 11 | labuan
# Processing Record 9 of Set 11 | kadirli
# Processing Record 10 of Set 11 | inhambane
# Processing Record 11 of Set 11 | suez
# Processing Record 12 of Set 11 | bathsheba
# Processing Record 13 of Set 11 | sisimiut
# Processing Record 14 of Set 11 | saurimo
# Processing Record 15 of Set 11 | burkburnett
# Processing Record 16 of Set 11 | satipo
# Processing Record 17 of Set 11 | portland
# Processing Record 18 of Set 11 | leiyang
# Processing Record 19 of Set 11 | kumluca
# Processing Record 20 of Set 11 | aranos
# Processing Record 21 of Set 11 | coaldale
# Processing Record 22 of Set 11 | argir
# Processing Record 23 of Set 11 | ajuchitlan
# Processing Record 24 of Set 11 | ormara
# Processing Record 25 of Set 11 | santiago
# Processing Record 26 of Set 11 | dutlwe
# Processing Record 27 of Set 11 | townsville
# Processing Record 28 of Set 11 | kitim
# Processing Record 29 of Set 11 | san juan
# Processing Record 30 of Set 11 | collipulli
# Processing Record 31 of Set 11 | sorland
# Processing Record 32 of Set 11 | beyneu
# Processing Record 33 of Set 11 | nuuk
# Processing Record 34 of Set 11 | makat
# Processing Record 35 of Set 11 | koumac
# Processing Record 36 of Set 11 | port hardy
# Processing Record 37 of Set 11 | shitanjing
# Processing Record 38 of Set 11 | todos santos
# Processing Record 39 of Set 11 | kokstad
# Processing Record 40 of Set 11 | inta
# Processing Record 41 of Set 11 | san antonio
# Processing Record 42 of Set 11 | urbino
# Processing Record 43 of Set 11 | masunga
# Processing Record 44 of Set 11 | joshimath
# Processing Record 45 of Set 11 | howard springs
# Processing Record 46 of Set 11 | salekhard
# Processing Record 47 of Set 11 | luan
# Processing Record 48 of Set 11 | alexandria
# Processing Record 49 of Set 11 | igrim
# Processing Record 0 of Set 12 | gagra
# Processing Record 1 of Set 12 | nyrob
# Processing Record 2 of Set 12 | codrington
# Processing Record 3 of Set 12 | churapcha
# Processing Record 4 of Set 12 | vao
# Processing Record 5 of Set 12 | canico
# Processing Record 6 of Set 12 | rocha
# Processing Record 7 of Set 12 | mecca
# Processing Record 8 of Set 12 | sao jose da coroa grande
# Processing Record 9 of Set 12 | paamiut
# Processing Record 10 of Set 12 | tirat karmel
# Processing Record 11 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 12 | galle
# Processing Record 13 of Set 12 | praya
# Processing Record 14 of Set 12 | uren
# Processing Record 15 of Set 12 | nacala
# Processing Record 16 of Set 12 | bereznik
# Processing Record 17 of Set 12 | porto velho
# Processing Record 18 of Set 12 | sucre
# Processing Record 19 of Set 12 | hastings
# Processing Record 20 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 12 | murovani kurylivtsi
# Processing Record 22 of Set 12 | meulaboh
# Processing Record 23 of Set 12 | arroyo
# Processing Record 24 of Set 12 | tilichiki
# Processing Record 25 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 12 | ilulissat
# Processing Record 27 of Set 12 | scottsbluff
# Processing Record 28 of Set 12 | kysyl-syr
# Processing Record 29 of Set 12 | douglas
# Processing Record 30 of Set 12 | makakilo city
# Processing Record 31 of Set 12 | cherskiy
# Processing Record 32 of Set 12 | bayan
# Processing Record 33 of Set 12 | anito
# Processing Record 34 of Set 12 | jatai
# Processing Record 35 of Set 12 | qasigiannguit
# Processing Record 36 of Set 12 | te anau
# Processing Record 37 of Set 12 | kampot
# Processing Record 38 of Set 12 | octeville
# Processing Record 39 of Set 12 | paita
# Processing Record 40 of Set 12 | cervo
# Processing Record 41 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 42 of Set 12 | kortkeros
# Processing Record 43 of Set 12 | zamberk
# Processing Record 44 of Set 12 | rincon
# Processing Record 45 of Set 12 | srivardhan
# Processing Record 46 of Set 12 | matias romero
# Processing Record 47 of Set 12 | turayf
# Processing Record 48 of Set 12 | katobu
# Processing Record 49 of Set 12 | sola
# Processing Record 0 of Set 13 | kruisfontein
# Processing Record 1 of Set 13 | avera
# Processing Record 2 of Set 13 | bagdarin
# Processing Record 3 of Set 13 | shahpur
# Processing Record 4 of Set 13 | lyngdal
# Processing Record 5 of Set 13 | golkoy
# Processing Record 6 of Set 13 | dalvik
# Processing Record 7 of Set 13 | aberdeen
# Processing Record 8 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 13 | sentyabrskiy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# [{'City': 'butaritari', 'Lat': 3.0707, 'Lng': 172.7902, 'Max Temp': 27.33, 'Humidity': 77, 'Cloudiness': 97, 'Wind Speed': 10.44, 'Country': 'KI', 'Date': 1675018021}, {'City': 'busselton', 'Lat': -33.65, 'Lng': 115.3333, 'Max Temp': 17.58, 'Humidity': 71, 'Cloudiness': 45, 'Wind Speed': 5.32, 'Country': 'AU', 'Date': 1675018022}, {'City': 'udupi', 'Lat': 13.35, 'Lng': 74.75, 'Max Temp': 25.58, 'Humidity': 84, 'Cloudiness': 75, 'Wind Speed': 1.92, 'Country': 'IN', 'Date': 1675018026}, {'City': 'craig', 'Lat': 40.5153, 'Lng': -107.5464, 'Max Temp': -2.01, 'Humidity': 79, 'Cloudiness': 100, 'Wind Speed': 2.06, 'Country': 'US', 'Date': 1675018029}, {'City': 'barrow', 'Lat': 71.2906, 'Lng': -156.7887, 'Max Temp': -18.99, 'Humidity': 78, 'Cloudiness': 100, 'Wind Speed': 4.12, 'Country': 'US', 'Date': 1675018035}, {'City': 'severo-kurilsk', 'Lat': 50.6789, 'Lng': 156.125, 'Max Temp': -1.99, 'Humidity': 95, 'Cloudiness': 100, 'Wind Speed': 15.07, 'Country': 'RU', 'Date': 1675018038}, {'City': 'kapaa', 'Lat': 22.0752, 'Lng': -159.319, 'Max Temp': 22.18, 'Humidity': 67, 'Cloudiness': 75, 'Wind Speed': 8.75, 'Country': 'US', 'Date': 1675017938}, {'City': 'jacobina', 'Lat': -11.1806, 'Lng': -40.5183, 'Max Temp': 31.97, 'Humidity': 27, 'Cloudiness': 0, 'Wind Speed': 4.49, 'Country': 'BR', 'Date': 1675018043}, {'City': 'punta arenas', 'Lat': -53.15, 'Lng': -70.9167, 'Max Temp': 17.06, 'Humidity': 42, 'Cloudiness': 0, 'Wind Speed': 9.77, 'Country': 'CL', 'Date': 1675018044}, {'City': 'quatre cocos', 'Lat': -20.2078, 'Lng': 57.7625, 'Max Temp': 26.16, 'Humidity': 82, 'Cloudiness': 100, 'Wind Speed': 1.19, 'Country': 'MU', 'Date': 1675018046}, {'City': 'sao filipe', 'Lat': 14.8961, 'Lng': -24.4956, 'Max Temp': 21.88, 'Humidity': 71, 'Cloudiness': 49, 'Wind Speed': 9.07, 'Country': 'CV', 'Date': 1675018049}, {'City': 'ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 11.81, 'Humidity': 66, 'Cloudiness': 75, 'Wind Speed': 8.23, 'Country': 'AR', 'Date': 1675018050}, {'City': 'lamu', 'Lat': -2.2717, 'Lng': 40.902, 'Max Temp': 26.12, 'Humidity': 85, 'Cloudiness': 100, 'Wind Speed': 6.57, 'Country': 'KE', 'Date': 1675018052}, {'City': 'oriximina', 'Lat': -1.7656, 'Lng': -55.8661, 'Max Temp': 28.85, 'Humidity': 66, 'Cloudiness': 77, 'Wind Speed': 0.46, 'Country': 'BR', 'Date': 1675018054}, {'City': 'bethel', 'Lat': 41.3712, 'Lng': -73.414, 'Max Temp': 10.3, 'Humidity': 62, 'Cloudiness': 100, 'Wind Speed': 2.57, 'Country': 'US', 'Date': 1675017910}, {'City': 'darlowo', 'Lat': 54.421, 'Lng': 16.4107, 'Max Temp': 3.19, 'Humidity': 91, 'Cloudiness': 100, 'Wind Speed': 11.15, 'Country': 'PL', 'Date': 1675017762}, {'City': 'cayenne', 'Lat': 4.9333, 'Lng': -52.3333, 'Max Temp': 27.02, 'Humidity': 74, 'Cloudiness': 100, 'Wind Speed': 7.2, 'Country': 'GF', 'Date': 1675018016}, {'City': 'airai', 'Lat': -8.9266, 'Lng': 125.4092, 'Max Temp': 16.08, 'Humidity': 92, 'Cloudiness': 100, 'Wind Speed': 0.52, 'Country': 'TL', 'Date': 1675018063}, {'City': 'borba', 'Lat': -4.3878, 'Lng': -59.5939, 'Max Temp': 26.42, 'Humidity': 75, 'Cloudiness': 100, 'Wind Speed': 0.87, 'Country': 'BR', 'Date': 1675018064}, {'City': 'mountain home', 'Lat': 43.133, 'Lng': -115.6912, 'Max Temp': -5.48, 'Humidity': 75, 'Cloudiness': 100, 'Wind Speed': 2.06, 'Country': 'US', 'Date': 1675018064}, {'City': 'hobart', 'Lat': -42.8794, 'Lng': 147.3294, 'Max Temp': 15.92, 'Humidity': 81, 'Cloudiness': 100, 'Wind Speed': 0.51, 'Country': 'AU', 'Date': 1675018065}, {'City': 'natal', 'Lat': -5.795, 'Lng': -35.2094, 'Max Temp': 31.36, 'Humidity': 61, 'Cloudiness': 40, 'Wind Speed': 6.69, 'Country': 'BR', 'Date': 1675018066}, {'City': 'kathmandu', 'Lat': 27.7167, 'Lng': 85.3167, 'Max Temp': 11.58, 'Humidity': 75, 'Cloudiness': 20, 'Wind Speed': 2.06, 'Country': 'NP', 'Date': 1675017628}, {'City': 'salalah', 'Lat': 17.0151, 'Lng': 54.0924, 'Max Temp': 21.05, 'Humidity': 28, 'Cloudiness': 0, 'Wind Speed': 4.12, 'Country': 'OM', 'Date': 1675017811}, {'City': 'nome', 'Lat': 64.5011, 'Lng': -165.4064, 'Ma ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  butaritari   3.0707  172.7902     27.33        77          97       10.44
# 1   busselton -33.6500  115.3333     17.58        71          45        5.32
# 2       udupi  13.3500   74.7500     25.58        84          75        1.92
# 3       craig  40.5153 -107.5464     -2.01        79         100        2.06
# 4      barrow  71.2906 -156.7887    -18.99        78         100        4.12
#
#   Country        Date
# 0      KI  1675018021
# 1      AU  1675018022
# 2      IN  1675018026
# 3      US  1675018029
# 4      US  1675018035

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        butaritari   3.0707  172.7902     27.33        77          97
# 1         busselton -33.6500  115.3333     17.58        71          45
# 2             udupi  13.3500   74.7500     25.58        84          75
# 3             craig  40.5153 -107.5464     -2.01        79         100
# 4            barrow  71.2906 -156.7887    -18.99        78         100
#
#          Wind Speed Country        Date
# City_ID
# 0             10.44      KI  1675018021
# 1              5.32      AU  1675018022
# 2              1.92      IN  1675018026
# 3              2.06      US  1675018029
# 4              4.12      US  1675018035

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter( "Lat", "Max Temp", c="indigo")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.title("City Latitude vs Temperature")
plt.grid(True, c="blue")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter( "Lat", "Humidity", c="blue")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title("City Latitude vs Humidity")
plt.grid(True, c="black")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter( "Lat", "Cloudiness", c="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs Humidity")
plt.grid(True, c="grey")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter( "Lat", "Wind Speed", c="brown")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs Wind Speed")
plt.grid(True, c="grey")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# Define a function to create Linear Regression plots

northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            butaritari   3.0707  172.7902     27.33        77          97
# 2                 udupi  13.3500   74.7500     25.58        84          75
# 3                 craig  40.5153 -107.5464     -2.01        79         100
# 4                barrow  71.2906 -156.7887    -18.99        78         100
# 5        severo-kurilsk  50.6789  156.1250     -1.99        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0             10.44      KI  1675018021
# 2              1.92      IN  1675018026
# 3              2.06      US  1675018029
# 4              4.12      US  1675018035
# 5             15.07      RU  1675018038

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df =city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           busselton -33.6500  115.3333     17.58        71          45
# 7            jacobina -11.1806  -40.5183     31.97        27           0
# 8        punta arenas -53.1500  -70.9167     17.06        42           0
# 9        quatre cocos -20.2078   57.7625     26.16        82         100
# 11            ushuaia -54.8000  -68.3000     11.81        66          75
#
#          Wind Speed Country        Date
# City_ID
# 1              5.32      AU  1675018022
# 7              4.49      BR  1675018043
# 8              9.77      CL  1675018044
# 9              1.19      MU  1675018046
# 11             8.23      AR  1675018050

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

(slope,intercept,rvalue,pvalue,stderr)=linregress(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"])

#regression values

regression= northern_hemi_df["Lat"]*slope+intercept

northern_hemi_df.plot.scatter("Lat","Max Temp", c= "violet")

plt.plot(northern_hemi_df["Lat"],regression, c="red")


#show formula & figure out positioning on graph

plt.annotate(f"y={round(slope,3)}x+{round(intercept,3)}",(10,-30),c="red",fontsize=15)

#add title

plt.title("Temperture vs Latitude - Northern Hemisphere")


plt.show()

# %%
# Linear regression on Southern Hemisphere

(slope,intercept,rvalue,pvalue,stderr)=linregress(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"])

#regression values

regressionsouth= southern_hemi_df["Lat"]*slope+intercept

southern_hemi_df.plot.scatter("Lat","Max Temp", c= "orange")

plt.plot(southern_hemi_df["Lat"],regressionsouth, c="red")


#show formula & figure out positioning on graph
plt.annotate(f"y={round(slope,3)}x+{round(intercept,3)}",(-50,35),c="red",fontsize=15)

#add title
plt.title("Temperture vs Latitude - Southern Hemisphere")


plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** While comparing temperature and latitude, both the Northern and Southern Hemispheres' appear to have a relatively strong linear correlation/rlationship. In th eNorthen Hemipshere, as latitude increases temperature generally decreases. The inverse is true for the Southern Hemisphere. This phenomena makes sense, the equator (lat 0) recieves the most direct sunlight along the earths axis, enabling more solar radiation. As cities geographic positioning is located further away from the equator, less solar radiation is present...resulting in lower temperatures as you approach the N/S poles.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere

(slope,intercept,rvalue,pvalue,stderr)=linregress(northern_hemi_df["Lat"],northern_hemi_df["Humidity"])

#regression values

regression= northern_hemi_df["Lat"]*slope+intercept

northern_hemi_df.plot.scatter("Lat","Humidity", c= "red")

plt.plot(northern_hemi_df["Lat"],regression, c="blue")


#show formula & figure out positioning on graph

plt.annotate(f"y={round(slope,3)}x+{round(intercept,3)}",(50,20),c="red",fontsize=15)

#add title

plt.title("Latitude vs Humidity - Northern Hemisphere")


plt.show()

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere

(slope,intercept,rvalue,pvalue,stderr)=linregress(southern_hemi_df["Lat"],southern_hemi_df["Humidity"])

#regression values

regressionsouth= southern_hemi_df["Lat"]*slope+intercept

southern_hemi_df.plot.scatter("Lat","Humidity", c= "grey")

plt.plot(southern_hemi_df["Lat"],regressionsouth, c="green")


#show formula & figure out positioning on graph
plt.annotate(f"y={round(slope,3)}x+{round(intercept,3)}",(-20,20),c="blue",fontsize=15)

#add title
plt.title("Latitude vs Humidity - Southern Hemisphere")


plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** Due to the spread of the city-data points a weak relationship seems present regarding latitude and humidity. However, the northern hemisphere seems to have a tighter spread and stronger correlation. Thi smakes sense because humidiy is determined by air temperature, location of nearest war body of water, and air movement. Temperture as shown in the last plots is related to longitude (possibly explaining why a weak relationship is present). But, cities proximity to water and air movement are not related to latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere

(slope,intercept,rvalue,pvalue,stderr)=linregress(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"])

#regression values

regression= northern_hemi_df["Lat"]*slope+intercept

northern_hemi_df.plot.scatter("Lat","Cloudiness", c= "black")

plt.plot(northern_hemi_df["Lat"],regression, c="green")


#show formula & figure out positioning on graph

plt.annotate(f"y={round(slope,3)}x+{round(intercept,3)}",(60,15),c="red",fontsize=15)

#add title

plt.title("Cloudiness vs Latitude - Northern Hemisphere")


plt.show()

# %%
# Southern Hemisphere

# Linear regression on Southern Hemisphere

(slope,intercept,rvalue,pvalue,stderr)=linregress(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"])

#regression values

regressionsouth= southern_hemi_df["Lat"]*slope+intercept

southern_hemi_df.plot.scatter("Lat","Cloudiness", c= "blue")

plt.plot(southern_hemi_df["Lat"],regressionsouth, c="red")


#show formula & figure out positioning on graph
plt.annotate(f"y={round(slope,3)}x+{round(intercept,3)}",(-50,85),c="red",fontsize=15)

#add title
plt.title("Temperture vs Latitude - Southern Hemisphere")


plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** Similar to the previous graphs relating to humidity, a wide spread of cities/points is displayed in either the Northern or Southern HEmispheres with very minimal correlation. The spread does not seem to indicate a relationship between cloudiness and latitude. This is too be expected due to the fact that cloudiness within an area is contributed to a muktitude of factors. Including: Rainfall, Sea Surface Temp, Air Temperature, and Iradiance.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Linear regression on Northern Hemisphere

(slope,intercept,rvalue,pvalue,stderr)=linregress(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"])

#regression values

regression= northern_hemi_df["Lat"]*slope+intercept

northern_hemi_df.plot.scatter("Lat","Wind Speed", c= "orange")

plt.plot(northern_hemi_df["Lat"],regression, c="black")


#show formula & figure out positioning on graph

plt.annotate(f"y={round(slope,3)}x+{round(intercept,3)}",(10,15),c="green",fontsize=15)

#add title

plt.title("Latitude vs Wind Speed - Northern Hemisphere")


plt.show()

# %%
# Southern Hemisphere


# Linear regression on Southern Hemisphere

(slope,intercept,rvalue,pvalue,stderr)=linregress(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"])

#regression values

regressionsouth= southern_hemi_df["Lat"]*slope+intercept

southern_hemi_df.plot.scatter("Lat","Wind Speed", c= "blue")

plt.plot(southern_hemi_df["Lat"],regressionsouth, c="red")


#show formula & figure out positioning on graph
plt.annotate(f"y={round(slope,3)}x+{round(intercept,3)}",(-50,12),c="red",fontsize=15)

#add title
plt.title("TLatitude vs Wind Speed - Southern Hemisphere")


plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** According to the graphs, Their appears to be a weak relationship between latitude and and wind speed. In both the Northern and Southern Hemisphere winds seem to have a wide degreee of variability with little relation to latitude. This is too be expected due to the fact that winds speeds are highly dependent on in situ geographic positioning. IE: location nearest mountaains, oceans, and other geologic features. Additionally wind speeds is dependent also on weather conditions.
